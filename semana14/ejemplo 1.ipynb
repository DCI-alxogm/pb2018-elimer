# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline     
#para activar los graficos en el notebook

# %%
#Opcion 1 para definir funciones 
fx=lambda x,y: x**2*np.cos(x/y)-3*x**3

# %%
#opcion 2 para definir funciones 
def fx2(x,y):
    z=x*y*np.cos(x/y)-3*x**3
    return z

# %%
x=np.linspace(-10,10,100)
x2=np.linspace(0,5,100)
z=fx(x,y)
#y=x**2*np.cos(x)-3*x**3
#y2=x2**2*np.cos(x2)-3*x2**3

# %%
plt.plot(x,z)
#plt.plot(x2,y2)

# %%
#plt.plot(x,fx2(1,2))

# %%
x3=np.random.rand(10)
fx2(x3,2)
# Out:
# array([ 0.46489754,  0.20848751,  0.38292143, -0.81993484,  0.5993578 ,
#        -1.11603779,  0.09602638,  0.28468275,  0.51581483,  0.42618462])

# %%
def recta(a,m=1,b=0,label='x'):
    z=m*a+b
    plt.plot(a,z,label=label)
    return

# %%
x=np.linspace(-2,2,20)
recta(x)
recta(x,-2,1,'-x+1')
plt.legend()

#plt.plot(x,recta(x,3))
#plt.plot(x,recta(x,-2,1))
#plt.plot(x,recta(x,1,-2))


plt.grid()
