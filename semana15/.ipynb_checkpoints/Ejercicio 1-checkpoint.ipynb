# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as cte
# %matplotlib inline

# %%
h=cte. Planck
k=cte. Boltzmann
c=cte. c
v=6
T=10

# %%
print (h,k,c)
# Out:
# 6.62607004e-34 1.38064852e-23 299792458.0

# %%
datos=np.loadtxt('IRCF.txt').T

# %%
k1=datos[0] #frecuencia
k2=datos[1]  #espectro
k3=datos[3]  #error

# %%
k3=k3*0.001

# %%
k1=k1*10000000000

# %%
plt.title('Radiacion cosmica de fondo de microondas')
plt.scatter(k1,k2)

# %% [markdown]
# # Grafica de error

# %%
plt.errorbar(k1,k2,k3)
#plt.subplot[2]
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
I=(((h*v**3)/(c**2))*(1/(np.exp((h*v)/k*T))-1))*10**(-26)

# %%
##Jansky o unidad de flujo es una unidad qe equivale a 10**(-26) vatios por metro cuadrado

# %%
print(I)
# Out:
# -4.5855613934214666e-83
